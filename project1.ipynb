# %%
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as graph
import seaborn as sns

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sri\\Desktop\\pythonBIT'

# %%
os.chdir('C:\\Users\\sri\\Desktop\\pythonBIT\\')

# %%
stud_data=pd.read_csv('Students_Data.csv')

# %%
# csv format data.
stud_data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# 5        F          KW       KuwaIT    lowerlevel    G-04         A
# 6        M          KW       KuwaIT  MiddleSchool    G-07         A
# 7        M          KW       KuwaIT  MiddleSchool    G-07         A
# 8        F          KW       KuwaIT  MiddleSchool    G-07         A
# 9        F          KW       KuwaIT  MiddleSchool    G-07         B
# 10       M          KW       KuwaIT  MiddleSchool    G-07         A
# 11       M          KW       KuwaIT  MiddleSchool    G-07         B
# 12       M          KW       KuwaIT    lowerlevel    G-04         A
# ...

# %%
# q1.student allocation by class.
stud_data.groupby(['Class']).size()
# Out:
# Class
# H    142
# L    127
# M    211
# dtype: int64

# %%
graph.figure(figsize=(10,10))
sns.countplot(data=stud_data,x = 'gender',hue ='Class')

# %%
# q2. student allocation by country(Nationality)
stud_data.groupby(['NationalITy']).size()
# Out:
# NationalITy
# Egypt            9
# Iran             6
# Iraq            22
# Jordan         172
# KW             179
# Lybia            6
# Morocco          4
# Palestine       28
# SaudiArabia     11
# Syria            7
# Tunis           12
# USA              6
# lebanon         17
# venzuela         1
# dtype: int64

# %%
graph.figure(figsize=(10,10))
sns.countplot(data=stud_data,x='NationalITy',hue= 'Class')

# %%
# q3. student performance.
stud_data.groupby(['ParentschoolSatisfaction','gender']).size()
# Out:
# ParentschoolSatisfaction  gender
# Bad                       F          58
#                           M         130
# Good                      F         117
#                           M         175
# dtype: int64

# %%
performance=stud_data.groupby(['ParentschoolSatisfaction','gender']).size()

# %%
# q4. who is better (girls or boys)?
performance['Good']
# Out:
# gender
# F    117
# M    175
# dtype: int64

# %%
# q5. dependence on basis of student absence over performance

stud_data.groupby(['StudentAbsenceDays','ParentschoolSatisfaction']).size()
# Out:
# StudentAbsenceDays  ParentschoolSatisfaction
# Above-7             Bad                         101
#                     Good                         90
# Under-7             Bad                          87
#                     Good                        202
# dtype: int64

# %%
# q6. scatter plot.
sb = seaborn.lmplot(data ='stud_data',x='ParentschoolSatisfaction',y='StudentAbsenceDays')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5cc70b1e791f> in <module>
#       1 # q6. scatter plot.
# ----> 2 sb = seaborn.lmplot(data ='stud_data',x='ParentschoolSatisfaction',y='StudentAbsenceDays')
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# ...
